# %%
from apyori import apriori
import pandas as pd
import numpy as np 

df = pd.read_excel(r'交易資料集.xlsx')

#數量為零或負值的交易代表退貨或註銷在前置處理中刪除
df_clear = df.drop(df[df['QUANTITY']<=0].index)

df_clear = df_clear.drop(columns=['ITEM_ID'])
df_clear = df_clear.drop(columns=['ITEM_NO'])
#df_clear = df_clear.drop(columns=['PRODUCT_TYPE'])
df_clear = df_clear.drop(columns=['CUST_ID'])
df_clear = df_clear.drop(columns=['TRX_DATE'])

df_clear = (df_clear
          .groupby(['INVOICE_NO', 'PRODUCT_TYPE'])['QUANTITY']
          .sum().unstack().reset_index().fillna(0)
          .set_index('INVOICE_NO'))

#清理只有一個item的交易

# 先挑出滿足條件的行
mask = (df_clear.iloc[:, 1:] > 0).sum(axis=1) == 1
# 刪除滿足條件的行
df_clear = df_clear.drop(df_clear[mask].index)

df_clear.to_csv("pretreatment.csv", encoding="utf-8")


print("欄位" + str(df_clear.columns))
print("數據量" + str(df_clear.shape))
# Out:
# 欄位Index(['CHIPSET / ASP', 'CPU / MPU', 'DISCRETE', 'LINEAR IC', 'LOGIC IC',
#        'MEMORY_EMBEDED', 'MEMORY_SYSTEM', 'OPTICAL AND SENSOR', 'OTHERS',
#        'PEMCO'],
#       dtype='object', name='PRODUCT_TYPE')
# 數據量(5131, 10)

# %%
def hot_encode(x):
    if(x<= 0):
        return False
    if(x>= 1):
        return True
    
# Encoding the datasets
df_clear_encoded = df_clear.applymap(hot_encode)

data = df_clear_encoded

#data.columns
data
# Out:
# PRODUCT_TYPE  CHIPSET / ASP  CPU / MPU  DISCRETE  LINEAR IC  LOGIC IC  \
# INVOICE_NO
# 5153                  False       True     False      False     False
# 216070003             False      False      True      False      True
# 216070004             False      False      True      False      True
# 216070011             False      False      True       True      True
# 216070018             False      False     False       True      True
# ...                     ...        ...       ...        ...       ...
# W016079115            False       True     False       True     False
# W016079116            False      False      True       True     False
# W016079120            False      False      True       True     False
# W016079121            False      False      True       True      True
# W016079133            False      False      True      False     False
#
# PRODUCT_TYPE  MEMORY_EMBEDED  MEMORY_SYSTEM  OPTICAL AND SENSOR  OTHERS  PEMCO
# INVOICE_NO
# 5153                   False          False               False    True  False
# 216070003              False          False               False   False  False
# 216070004              False          False               False   False  False
# 216070011              False          False               False   False  False
# 216070018               True          False               False   False  False
# ...                      ...            ...                 ...     ...    ...
# W016079115             False          False               False   False  False
# W016079116             False          False               False    True  False
# W016079120             False          False               False   False  False
# W016079121              True          False               False   False  False
# W016079133             False          False               False    True  False
#
# [5131 rows x 10 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules
#min_support最低支持度
#use_colnames轉換對應的物品(itemsets)

frq_items = apriori(data, min_support = 0.00395, use_colnames = True)
frq_items
# Out:
#      support                                           itemsets
# 0   0.256090                                    (CHIPSET / ASP)
# 1   0.110700                                        (CPU / MPU)
# 2   0.406938                                         (DISCRETE)
# 3   0.501657                                        (LINEAR IC)
# 4   0.411616                                         (LOGIC IC)
# ..       ...                                                ...
# 87  0.007211             (PEMCO, DISCRETE, LOGIC IC, LINEAR IC)
# 88  0.004288      (DISCRETE, MEMORY_EMBEDED, LINEAR IC, OTHERS)
# 89  0.004093  (DISCRETE, OPTICAL AND SENSOR, LINEAR IC, OTHERS)
# 90  0.004288   (DISCRETE, OPTICAL AND SENSOR, LOGIC IC, OTHERS)
# 91  0.004677  (DISCRETE, LOGIC IC, MEMORY_EMBEDED, CPU / MPU...
#
# [92 rows x 2 columns]

# %%
#找規則
#confidence 
#metric感興趣的指標'support'、'confidence'
#min threshold感性指標的最低標準
rules = association_rules(frq_items, metric='confidence', min_threshold=0.8)
rules_df = pd.DataFrame(rules)
rules_df.to_csv("apriori_rules.csv", encoding="utf-8", index=False)
rules
# Out:
#                                          antecedents            consequents  \
# 0                               (OPTICAL AND SENSOR)             (DISCRETE)
# 1                          (DISCRETE, CHIPSET / ASP)            (LINEAR IC)
# 2                          (LOGIC IC, CHIPSET / ASP)            (LINEAR IC)
# 3                         (MEMORY_SYSTEM, LINEAR IC)             (DISCRETE)
# 4                          (LOGIC IC, MEMORY_SYSTEM)             (DISCRETE)
# 5                     (OPTICAL AND SENSOR, LOGIC IC)             (DISCRETE)
# 6                                  (PEMCO, LOGIC IC)             (DISCRETE)
# 7                (DISCRETE, LOGIC IC, CHIPSET / ASP)            (LINEAR IC)
# 8                    (DISCRETE, LOGIC IC, CPU / MPU)            (LINEAR IC)
# 9              (DISCRETE, MEMORY_EMBEDED, CPU / MPU)            (LINEAR IC)
# 10            (MEMORY_EMBEDED, CPU / MPU, LINEAR IC)             (DISCRETE)
# 11             (DISCRETE, MEMORY_EMBEDED, CPU / MPU)             (LOGIC IC)
# 12             (MEMORY_EMBEDED, LOGIC IC, CPU / MPU)             (DISCRETE)
# 13             (MEMORY_EMBEDED, LOGIC IC, CPU / MPU)            (LINEAR IC)
# 14         (OPTICAL AND SENSOR, LOGIC IC, LINEAR IC)             (DISCRETE)
# 15                      (DISCRETE, LOGIC IC, OTHERS)            (LINEAR IC)
# 16                      (PEMCO, LOGIC IC, LINEAR IC)             (DISCRETE)
# 17                (DISCRETE, MEMORY_EMBEDED, OTHERS)            (LINEAR IC)
# 18               (MEMORY_EMBEDED, LINEAR IC, OTHERS)             (DISCRETE)
# 19           (OPTICAL AND SENSOR, LINEAR IC, OTHERS)             (DISCRETE)
# 20            (OPTICAL AND SENSOR, LOGIC IC, OTHERS)             (DISCRETE)
# 21   (DISCRETE, MEMORY_EMBEDED, LOGIC IC, CPU / MPU)            (LINEAR IC)
# 22  (DISCRETE, MEMORY_EMBEDED, CPU / MPU, LINEAR IC)             (LOGIC IC)
# 23  (MEMORY_EMBEDED, LOGIC IC, CPU / MPU, LINEAR IC)             (DISCRETE)
# 24             (MEMORY_EMBEDED, LOGIC IC, CPU / MPU)  (DISCRETE, LINEAR IC)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.049113            0.406938  0.039563    0.805556  1.979552
# 1             0.008575            0.501657  0.007601    0.886364  1.766873
# 2             0.007991            0.501657  0.006626    0.829268  1.653060
# 3             0.005262            0.406938  0.004288    0.814815  2.002306
# 4             0.004483            0.406938  0.004288    0.956522  2.350533
# 5             0.017346            0.406938  0.015592    0.898876  2.208877
# 6             0.012278            0.406938  0.010134    0.825397  2.028310
# 7             0.005262            0.501657  0.004872    0.925926  1.845737
# 8             0.014812            0.501657  0.012083    0.815789  1.626191
# 9             0.006431            0.501657  0.005652    0.878788  1.751772
# 10            0.006431            0.406938  0.005652    0.878788  2.159512
# 11            0.006431            0.411616  0.005262    0.818182  1.987732
# 12            0.005847            0.406938  0.005262    0.900000  2.211638
# 13            0.005847            0.501657  0.004872    0.833333  1.661163
# 14            0.010914            0.406938  0.009940    0.910714  2.237967
# 15            0.019684            0.501657  0.015786    0.801980  1.598664
# 16            0.007991            0.406938  0.007211    0.902439  2.217632
# 17            0.004483            0.501657  0.004288    0.956522  1.906726
# 18            0.005067            0.406938  0.004288    0.846154  2.079318
# 19            0.004288            0.406938  0.004093    0.954545  2.345677
# 20            0.004677            0.406938  0.004288    0.916667  2.252594
# 21            0.005262            0.501657  0.004677    0.888889  1.771907
# 22            0.005652            0.411616  0.004677    0.827586  2.010580
# 23            0.004872            0.406938  0.004677    0.960000  2.359080
# 24            0.005847            0.248295  0.004677    0.800000  3.221978
#
#     leverage  conviction  zhangs_metric
# 0   0.019577    3.050032       0.520394
# 1   0.003299    4.385422       0.437783
# 2   0.002618    2.918869       0.398243
# 3   0.002146    3.202534       0.503224
# 4   0.002464   13.640421       0.577152
# 5   0.008533    5.864722       0.556942
# 6   0.005138    3.396627       0.513281
# 7   0.002233    6.727636       0.460635
# 8   0.004653    2.705293       0.390855
# 9   0.002426    4.111333       0.431927
# 10  0.003035    4.892760       0.540408
# 11  0.002615    3.236114       0.500131
# 12  0.002883    5.930618       0.551068
# 13  0.001939    2.990060       0.400353
# 14  0.005498    6.642292       0.559270
# 15  0.005912    2.516634       0.381997
# 16  0.003959    6.078883       0.553491
# 17  0.002039   11.461898       0.477682
# 18  0.002226    3.854902       0.521717
# 19  0.002348   13.047359       0.576154
# 20  0.002384    7.116741       0.558681
# 21  0.002038    4.485091       0.437941
# 22  0.002351    3.412629       0.505488
# 23  0.002695   14.826545       0.578927
# 24  0.003226    3.758527       0.693688

# %%
from time import time

#現在時間
to = time()
frq_items = apriori(data, min_support = 0.00395, use_colnames = True)
rules = association_rules(frq_items)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#結束時間
time = time() - to
print("花費時間"+ str(time))
# Out:
# 花費時間0.01499629020690918

# %%
# 定義一個函數，將字符串轉換為列表
def string_to_list(string):
    string = string.replace("frozenset({'", "")
    string = string.replace("'})", "")
    string = string.replace("'", "")
    string = string.split(", ")
    return string

rules_df = pd.read_csv(r'apriori_rules.csv')
user_input = input("請輸入您想購買的產品名稱：")
item = user_input.split(',')
prediction_items = list(map(str, item))

#集合
item = []
item = set(item)

for index, row in rules_df.iterrows():
    #處理規則(轉成list)
    rules = string_to_list(row['antecedents'])
    if set(prediction_items).issubset(rules):
        item.update(string_to_list(row['consequents']))
print("為您推薦其他的產品:" + str(item))
# Out:
# 請輸入您想購買的產品名稱：DISCRETE
# 為您推薦其他的產品:{'LOGIC IC', 'LINEAR IC'}

# %%
import time
def apriori_test(ms, mt,data): 
   
    frq_items = apriori(data, min_support = ms, use_colnames = True)
    rules = association_rules(frq_items, metric='confidence', min_threshold=mt)
    return rules


data = df_clear_encoded
# print(data)
min_support =  np.arange(0.00195, 0.004, 0.00025)
min_confidence = np.arange(0.6, 0.8, 0.05)
times = []
min_support_l = []
min_confidence_l = []
rule = []

for ms in min_support:
    for mt in min_confidence:
        #現在時間
        to = time.time()
        rules = apriori_test(ms, mt,data)
        #結束時間
#         print(e)
        time_d = time.time() - to
        dd = pd.DataFrame(rules)
        e = len(dd)
        min_support_l.append(ms)
        min_confidence_l.append(mt)
        times.append(time_d)
        rule.append(e)
df = {
    "minSupport": min_support_l,
    "minConfidence": min_confidence_l,
    "time(s)": times,
    "count": rule
}
df = pd.DataFrame(df)
df
# Out:
#     minSupport  minConfidence   time(s)  count
# 0      0.00195           0.60  0.016002    140
# 1      0.00195           0.65  0.013028    124
# 2      0.00195           0.70  0.012998    106
# 3      0.00195           0.75  0.012995     81
# 4      0.00195           0.80  0.012007     57
# 5      0.00220           0.60  0.012001    127
# 6      0.00220           0.65  0.013000    113
# 7      0.00220           0.70  0.011993     97
# 8      0.00220           0.75  0.011006     72
# 9      0.00220           0.80  0.012971     51
# 10     0.00245           0.60  0.011028    115
# 11     0.00245           0.65  0.012987    101
# 12     0.00245           0.70  0.012015     87
# 13     0.00245           0.75  0.010999     66
# 14     0.00245           0.80  0.010999     48
# 15     0.00270           0.60  0.011972    114
# 16     0.00270           0.65  0.012000    101
# 17     0.00270           0.70  0.012000     87
# 18     0.00270           0.75  0.013030     66
# 19     0.00270           0.80  0.010997     48
# 20     0.00295           0.60  0.011001    110
# 21     0.00295           0.65  0.010972     97
# 22     0.00295           0.70  0.012000     83
# 23     0.00295           0.75  0.011000     62
# 24     0.00295           0.80  0.011000     46
# 25     0.00320           0.60  0.011999    102
# 26     0.00320           0.65  0.011000     89
# 27     0.00320           0.70  0.010999     77
# 28     0.00320           0.75  0.011001     58
# 29     0.00320           0.80  0.012031     43
# 30     0.00345           0.60  0.011000     82
# 31     0.00345           0.65  0.009999     70
# 32     0.00345           0.70  0.010001     59
# 33     0.00345           0.75  0.010999     43
# 34     0.00345           0.80  0.011003     32
# 35     0.00370           0.60  0.011000     74
# 36     0.00370           0.65  0.010998     64
# 37     0.00370           0.70  0.010999     53
# 38     0.00370           0.75  0.010999     38
# 39     0.00370           0.80  0.011000     27
# 40     0.00395           0.60  0.009972     69
# 41     0.00395           0.65  0.010999     59
# 42     0.00395           0.70  0.011003     48
# 43     0.00395           0.75  0.011010     35
# 44     0.00395           0.80  0.009990     24

# %%
import time
from mlxtend.frequent_patterns import fpgrowth
def fpgrowth_test(ms, mt,data): 
    #現在時間
    #to = time()
    fpg = fpgrowth(data, min_support = ms, use_colnames = True)
    rules = association_rules(fpg, metric='confidence', min_threshold=mt)
    return rules


data = df_clear_encoded
#print(data)
min_support =  np.arange(0.00195, 0.004, 0.00025)
min_confidence = np.arange(0.6, 0.8, 0.05)
times = []
min_support_l = []
min_confidence_l = []
rule = []

for ms in min_support:
    for mt in min_confidence:
        #現在時間
        to = time.time()
        rules = fpgrowth_test(ms, mt,data)
        #結束時間
#        print(e)
        time_d = time.time() - to
        dd = pd.DataFrame(rules)
        e = len(dd)
        min_support_l.append(ms)
        min_confidence_l.append(mt)
        times.append(time_d)
        rule.append(e)
df = {
    "minSupport": min_support_l,
    "minConfidence": min_confidence_l,
    "time(s)": times,
    "count": rule
}
df_a = pd.DataFrame(df)
df_a
# Out:
#     minSupport  minConfidence   time(s)  count
# 0      0.00195           0.60  0.043996    140
# 1      0.00195           0.65  0.040001    124
# 2      0.00195           0.70  0.034000    106
# 3      0.00195           0.75  0.046001     81
# 4      0.00195           0.80  0.037999     57
# 5      0.00220           0.60  0.035026    127
# 6      0.00220           0.65  0.034997    113
# 7      0.00220           0.70  0.032979     97
# 8      0.00220           0.75  0.033027     72
# 9      0.00220           0.80  0.032970     51
# 10     0.00245           0.60  0.032023    115
# 11     0.00245           0.65  0.032009    101
# 12     0.00245           0.70  0.039970     87
# 13     0.00245           0.75  0.028027     66
# 14     0.00245           0.80  0.028974     48
# 15     0.00270           0.60  0.034021    114
# 16     0.00270           0.65  0.029006    101
# 17     0.00270           0.70  0.034973     87
# 18     0.00270           0.75  0.034998     66
# 19     0.00270           0.80  0.039018     48
# 20     0.00295           0.60  0.038996    110
# 21     0.00295           0.65  0.033988     97
# 22     0.00295           0.70  0.034000     83
# 23     0.00295           0.75  0.034997     62
# 24     0.00295           0.80  0.030031     46
# 25     0.00320           0.60  0.027997    102
# 26     0.00320           0.65  0.032003     89
# 27     0.00320           0.70  0.034968     77
# 28     0.00320           0.75  0.038004     58
# 29     0.00320           0.80  0.028024     43
# 30     0.00345           0.60  0.030001     82
# 31     0.00345           0.65  0.028973     70
# 32     0.00345           0.70  0.033026     59
# 33     0.00345           0.75  0.029970     43
# 34     0.00345           0.80  0.033000     32
# 35     0.00370           0.60  0.035001     74
# 36     0.00370           0.65  0.032028     64
# 37     0.00370           0.70  0.026002     53
# 38     0.00370           0.75  0.028002     38
# 39     0.00370           0.80  0.029970     27
# 40     0.00395           0.60  0.028026     69
# 41     0.00395           0.65  0.028000     59
# 42     0.00395           0.70  0.030000     48
# 43     0.00395           0.75  0.030972     35
# 44     0.00395           0.80  0.030001     24
